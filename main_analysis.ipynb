# %% [markdown]
# # 1. Analyze how individual factors influence flight delay

# %% [markdown]
# ## 1.1 Day-of-Week

# %%
from src.day_of_week import DayOfWeekAnalysis
DayOfWeekAnalyzer = DayOfWeekAnalysis("Cleaned_Airline_Data.csv")

# %%
DayOfWeekAnalyzer.delay_distribution()
# Out:
#         DayOfWeek   ARR_DELAY
# count  1200874.00  1200874.00
# mean         2.93        0.54
# std          1.91       42.66
# min          0.00      -96.00
# 25%          1.00      -16.00
# 50%          3.00       -8.00
# 75%          4.00        3.00
# max          6.00     1843.00

# %%
DayOfWeekAnalyzer.delay_distribution_by_day()
# Out:
#      ARR mean (min)  ARR median (min)  ARR std
# Day
# Mon            1.20              -8.0    42.51
# Tue            1.90              -9.0    47.03
# Wed           -0.69              -9.0    39.29
# Thu            0.59              -8.0    42.51
# Fri            1.92              -7.0    45.26
# Sat            0.76              -8.0    44.17
# Sun           -1.91              -9.0    37.52

# %%
DayOfWeekAnalyzer.mean_delay_by_day_bar_plot()
DayOfWeekAnalyzer.delay_percentage_by_day_line_plot()
DayOfWeekAnalyzer.delay_category_by_day_bar_plot()

# %% [markdown]
# # 2. Analyze how combination of factors determines flight delay
